# %%
from IPython.display import YouTubeVideo
YouTubeVideo('CvSOaYi89B4')

# %%
# Modified and coded version of Zelle Future Value example listed in Chapter 2
principal = float(input('Enter the initial principal: '))
apr = float(input('Enter the annualized interest rate: '))
def main(): print ('This program calculates the future value of a 10-year investment.')
for i in range(10):principal = principal * (1 + apr)
print ('The amount in 10 years is:', principal)

main()
# Out:
# Enter the initial principal:  500
# Enter the annualized interest rate:  0.01
# The amount in 10 years is: 552.3110627056022
# This program calculates the future value of a 10-year investment.

# %%
#function name is main
#expression is for i in range(10):principal = principal * (1 + apr)  which calcylated the future value
#output statement isprint ('This program calculates the future value of a 10-year investment.') and
#print ('The amount in 10 years is:', principal)  principal is output value and this function also out print two string sentence
#a simple variable assignment is Enter the initial principal:  500  the value 500 is assigned to variable principal

# %%
#requirements The people who come from china not familiar with which cause inconvenient, this program is use for convert value from ounces 
# to grams.
#Specifications development: ounces to grams converter program specifications: Develop a conversion function
#which will convert from ounces to grams. The user will invoke the function or will be prompted to input 
#the weight in ounces to convert from ounces to grams. The output will then be displayed in grams.
# pseudocode grams = ounces/0.035274  the convert function will use this equation.

# the program to convert from ounces to grams

ounces = float(input('Enter the ounces: '))
def convert(): print ('This program convert value from ounces to grams.')
grams = ounces / 0.035274
print ('The value in grams is:', grams)
convert()
# Out:
# Enter the ounces:  1
# The value in grams is: 28.34949254408346
# This program convert value from ounces to grams.
